# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## To delete starting 111 rows of all csv files

# %% [markdown]
# ## To annotate (not working properly)

# %%
def annot_max(x,y, ax=None):
    xmax = x
    ymax = y
    text= "x={:.3f}, y={:.3f}".format(xmax, ymax)
    if not ax:
        ax=plt.gca()
    bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
    arrowprops=dict(arrowstyle="->",connectionstyle="angle,angleA=0,angleB=60")
    kw = dict(xycoords='data',textcoords="axes fraction",
              arrowprops=arrowprops, bbox=bbox_props, ha="right", va="top")
    ax.annotate(text, xy=(xmax, ymax), xytext=(0.94,0.96), **kw)

# annot_max(x,y)

# %% [markdown]
# ## Using glob to plot all the csv files in a folder

# %%
import glob

myfiles = glob.glob('./Diode/files/*.csv')
for file in myfiles:
    print(file)
    plt.rcParams["figure.figsize"] = [7.00, 3.50]
    plt.rcParams["figure.autolayout"] = True
    plt.title(f"I vs V of file{file}")
    plt.xlabel("V")
    plt.ylabel("I")
    columns = ["V1", "I1"]
    df = pd.read_csv(file, usecols=columns)
    # print("Contents in csv file:", df)
    plt.plot(df.V1, df.I1)
    plt.show()
# Out:
# ./Diode/files/I_V Sweep [D1-1; 1_18_2023 3_01_57 PM].csv
# ./Diode/files/I_V Sweep [-6; 1_18_2023 4_04_58 PM].csv
# ./Diode/files/I_V Sweep [Diode1-13; 1_18_2023 4_19_50 PM].csv
# ./Diode/files/I_V Sweep [Diode1-11; 1_18_2023 4_18_16 PM].csv
# ./Diode/files/I_V Sweep [-9; 1_18_2023 4_11_38 PM].csv
# ./Diode/files/I_V Sweep [D1-3; 1_18_2023 2_48_39 PM].csv

# %% [markdown]
# ## log(I) vs V

# %%
for file in myfiles:
    plt.rcParams["figure.figsize"] = [7.00, 3.50]
    plt.rcParams["figure.autolayout"] = True
    plt.title(f"log(I) vs V of file{file}")
    plt.xlabel("V")
    plt.ylabel("log(I)")
    columns = ["V1", "I1"]
    df = pd.read_csv(file, usecols=columns)
    Vmax = [np.argmax(np.gradient(np.log(df.I1))/np.gradient(np.log(df.V1)))]
    Imax = (np.gradient(np.log(df.I1))/np.gradient(np.log(df.V1))).max()
    xy=(np.array(df.V1)[Vmax][0],np.array(df.I1)[Vmax][0])
    print(xy)
    
    
    plt.plot(df.V1,np.log(df.I1))
    plt.annotate(f'({np.array(df.V1)[Vmax][0],np.array(df.I1)[Vmax][0]})', xy=(np.array(df.V1)[Vmax][0],np.log(np.array(df.I1)[Vmax][0])), xytext=(np.array(df.V1)[Vmax]+0.2,np.log(np.array(df.I1)[Vmax][0])),
             arrowprops=dict(facecolor='black', shrink=0.05))
    plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# (0.441, 3.64559e-05)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# (0.007, 1.097e-10)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# (0.43, 2.72543e-05)
# ...

# %% [markdown]
# ## α vs V plot

# %%
i = 1
for file in myfiles:
    if i > 0:
        plt.title(f"α vs V plot of file{file}")
        plt.rcParams["figure.figsize"] = [7.00, 3.50]
        plt.rcParams["figure.autolayout"] = True
        plt.xlabel("V")
        plt.ylabel("α")
        columns = ["V1", "I1"]
        df = pd.read_csv(file, usecols=columns)
        Vmax = [np.argmax(np.gradient(np.log(df.I1))/np.gradient(np.log(df.V1)))]
        Imax = (np.gradient(np.log(df.I1))/np.gradient(np.log(df.V1))).max()
        max_index = np.argmax(np.gradient(np.log(df.I1))/np.gradient(np.log(df.V1)))
        # print(np.array(df.V1)[max_index],np.array(np.gradient(np.log(df.I1))/np.gradient(np.log(df.V1)))[max_index],df.I1[max_index])
        # print(df.V1,np.gradient(np.log(df.I1))/np.gradient(np.log(df.V1)),df.I1)
        plt.plot(df.V1,np.gradient(np.log(df.I1))/np.gradient(np.log(df.V1)))
        # Annotate the point at (3, 6)
        plt.annotate(f'({np.array(df.V1)[Vmax][0]}, {Imax})', xy=(np.array(df.V1)[Vmax][0],Imax), xytext=(np.array(df.V1)[Vmax]+0.2,Imax),
             arrowprops=dict(facecolor='red', shrink=0.02))
        print(Vmax,Imax)
        plt.show()
        # if i > 0:
        #     print(f"V = {np.array(df.V1)[i]}, alpha = {np.gradient(np.log(df.I1)[i])/np.gradient(np.log(df.V1)[i])}")
        i += 1
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# [63] 10.946577359538965
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# [200] nan
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# [43] 10.906806172272178
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants
h = 6.626e-34  # Planck constant
c = 3e8  # Speed of light
k = 1.38e-23  # Boltzmann constant
T = 300  # Temperature in Kelvin
q = 1.6e-19  # Electron charge
n = 1.5  # Refractive index of the solar cell

# Bandgap range
Eg = np.linspace(0.1, 3.5, 100)  # Bandgap in eV

# Calculation of parameters
eta_c = 1 - 0.5 * np.sqrt(Eg / (Eg + 0.8))
eta_t = ((n * Eg) ** 0.5 - n * Eg) / ((n * Eg) ** 0.5 + n * Eg)
eta_r = ((n * Eg) ** 0.5 - 1) / ((n * Eg) ** 0.5 + 1)
eta_q = 1 - np.exp(-q * Eg / (k * T))
eta_ext = 0.75

J_sc = q * n ** 2 * c * (Eg * 1.6e-19) ** 2 / (2 * h ** 3) * \
    (1 - np.exp(-q * Eg / (k * T)))
V_oc = k * T / q * np.log(J_sc / (q * n ** 2 * c))

P_in = 1000  # Power density of incoming photons in W/m^2

# Calculation of maximum PCE
PCE_max = (eta_c * eta_t * eta_r * eta_q * eta_ext) * (J_sc * V_oc / P_in)

# Plotting
plt.plot(Eg, PCE_max * 100)
plt.xlabel('Bandgap (eV)')
plt.ylabel('Maximum Power Conversion Efficiency (%)')
plt.title('Shockley-Queisser Limit')
plt.show()
